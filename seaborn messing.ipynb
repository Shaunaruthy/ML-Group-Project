# %%
import os
import numpy as np 
import pandas as pd
os.getcwd()
# Out:
# 'C:\\Users\\Shauna McGeever\\Desktop\\Machine Learning- Group Project'

# %%
data = pd.read_csv("merged_files.csv")
data = pd.DataFrame(data)
data.head()
# Out:
#    Unnamed: 0  STATION ID                 TIME              NAME  BIKE STANDS  \
# 0       17856          69  2020-04-01 00:00:00  GRAND CANAL DOCK           40
# 1       17868          69  2020-04-01 01:00:00  GRAND CANAL DOCK           40
# 2       17880          69  2020-04-01 02:00:00  GRAND CANAL DOCK           40
# 3       17892          69  2020-04-01 03:00:00  GRAND CANAL DOCK           40
# 4       17904          69  2020-04-01 04:00:00  GRAND CANAL DOCK           40
#
#    AVAILABLE BIKE STANDS  AVAILABLE BIKES  Usage
# 0                     29               11   72.5
# 1                     29               11   72.5
# 2                     29               11   72.5
# 3                     29               11   72.5
# 4                     29               11   72.5

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# import Pandas libraries
import pandas as pd

sns.set_theme()

data["datetime"] = pd.to_datetime(data["TIME"])
data["month"] = data["datetime"].dt.month
data = data[data['month'] != 1]
data.head()


mean = np.mean(data["Usage"])
median = np.median(data["Usage"])
std_dev = np.std(data["Usage"])
variance = np.var(data["Usage"])


data



sns.lineplot(data=data, x='month', y='Usage')




#sns.histplot(data=data, x='Usage', bins=10, kde='true')

sns.displot(data=data, x= 'Usage', col='NAME', bins=10, col_wrap=3)

sns.catplot(kind='strip', data=data, x='NAME', y='Usage', aspect=2)

sns.catplot(data=data, kind='box', x='NAME', y='Usage', aspect=2)

sns.catplot(kind='bar',data=data,x='NAME',y='Usage',aspect=2)

# %%
sns.lineplot(data=data, x='month', y='Usage', hue = 'NAME')

#Need to fix where the legend is lool
# Out:
# <AxesSubplot:xlabel='month', ylabel='Usage'>
