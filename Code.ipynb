# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import matplotlib.pyplot as plt
# Classifiers
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
# Evaluation tools
from sklearn.metrics import plot_confusion_matrix
# CV
from sklearn.model_selection import cross_val_score

# %%
dataset = pd.read_csv("dublinbikes_2020_firstQ.csv")
station = np.unique(dataset['NAME'])
print(station)


#print(dataset["BIKE STANDS"] == 40)

#How do we chose our three stations? Based on area? bike stand
#EG Tourist area = PRINCES STREET / O'CONNELL STREET 
#Buisness Area = CUSTOM HOUSE
#Residential Area = JAMES STREET (NORTH INNER CITY is the most populated residential area in Dublin)

mask_oconnell = dataset.NAME == "PRINCES STREET / O'CONNELL STREET"
oconnell_data = dataset[mask_oconnell]
#print(oconnell_data)

mask_customhouse = dataset.NAME == "CUSTOM HOUSE"
customhouse_data = dataset[mask_customhouse]
#print(customhouse_data)

mask_js = dataset.NAME == "JAMES STREET"
js_data = dataset[mask_js]
#print(js_data)


s = pd.concat([oconnell_data,customhouse_data,js_data])
print(s)
# Out:
# ['AVONDALE ROAD' 'BENSON STREET' 'BLACKHALL PLACE' 'BLESSINGTON STREET'
#  'BOLTON STREET' 'BROADSTONE' 'BROOKFIELD ROAD' 'BUCKINGHAM STREET LOWER'
#  'CATHAL BRUGHA STREET' 'CHARLEMONT PLACE' 'CHARLEVILLE ROAD'
#  'CHRISTCHURCH PLACE' 'CITY QUAY' 'CLONMEL STREET'
#  'COLLINS BARRACKS MUSEUM' 'CONVENTION CENTRE' 'CUSTOM HOUSE'
#  'CUSTOM HOUSE QUAY' 'DAME STREET' 'DENMARK STREET GREAT' 'DEVERELL PLACE'
#  'EARLSFORT TERRACE' 'ECCLES STREET' 'ECCLES STREET EAST' 'EMMET ROAD'
#  'EXCHEQUER STREET' 'EXCISE WALK' 'FENIAN STREET'
#  'FITZWILLIAM SQUARE EAST' 'FITZWILLIAM SQUARE WEST' 'FRANCIS STREET'
#  'FREDERICK STREET SOUTH' 'GEORGES LANE' 'GEORGES QUAY' 'GOLDEN LANE'
#  'GRAND CANAL DOCK' 'GRANGEGORMAN LOWER (CENTRAL)'
#  'GRANGEGORMAN LOWER (NORTH)' 'GRANGEGORMAN LOWER (SOUTH)'
#  'GRANTHAM STREET' 'GRATTAN STREET' 'GREEK STREET' 'GUILD STREET'
#  'HANOVER QUAY' 'HANOVER QUAY EAST' 'HARCOURT TERRACE' 'HARDWICKE PLACE'
# ...
